# %% [markdown]
# <a href="https://colab.research.google.com/github/Humerathestar1/python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# Sample Data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]
# Creating a simple line plot
plt.plot(x, y, marker='o', linestyle='-', color='b', label='Line Graph')
# Customization
plt.title("Simple Line Plot")
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.legend()
plt.grid(True)
# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Load a sample dataset
tips = sns.load_dataset("tips")
# Creating a scatter plot with Seaborn
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="day", style="sex")
# Customization
plt.title("Total Bill vs Tip Amount")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
# Show plot
plt.show()
